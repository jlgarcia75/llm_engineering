# %% [markdown]
# # Challenge
# Add Gemini to closed source mix
# More open-source models such as CodeLlama and Starcoder, get CodeGemma to work
#
# # New things to do
# A code tool that automatically adds docstring/comments
# A code gen tool that writes unit test cases
# A code gen tool that writes trading code to buy and sell equities in a simulated environment, based on a given API
